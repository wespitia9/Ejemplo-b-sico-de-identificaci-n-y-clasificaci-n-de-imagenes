# %% [markdown]
# <a href="https://colab.research.google.com/github/wespitia9/Ejemplo-b-sico-de-identificaci-n-y-clasificaci-n-de-imagenes/blob/main/Ejemplo_b%C3%A1sico_de_identificaci%C3%B3n_y_clasificaci%C3%B3n_de_imagenes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instalamos del repositorio los archivos necesarios, en este caso usaremos el modelo Yolo v5, éste modelo está caracterizado por su velocidad y precisión.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies
 
import torch
from IPython.display import Image, clear_output  # to display images
 
clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.13.1+cu116 (CPU)

# %% [markdown]
# Carguemos la imagen que deseamos analizar, podemos descargarla igualmente de la web y guardarla localmente para luego usarla

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8ee5e65b-9223-492e-ae72-ea0b7126fea0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ee5e65b-9223-492e-ae72-ea0b7126fea0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Procedamos a ejecutar la función de detección

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source sesion.jpg
#Image(filename='runs/detect/imagen.jpg', width=600)
# Out:
# detect: weights=['yolov5s.pt'], source=sesion.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 42.6MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/yolov5/sesion.jpg: 640x512 9 persons, 4 chairs, 1 tv, 7 laptops, 1 mouse, 1 keyboard, 2 books, 728.8ms
# Speed: 1.9ms pre-process, 728.8ms inference, 24.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# Visualizamos el resultado del procesamiento del algoritmo siguiendo la ruta que nos arroja la celda anterior, esta ruta también puedes obtenerla abriendo la carpeta que aparece a la izquierda, en Yolo y la subcarpeta detect, copiando la ruta de la imagen procesada

# %%
Image(filename='/content/yolov5/runs/detect/exp/sesion.jpg', width=600)
